# %%
# %%file model.py

from accelerate import Accelerator
#accelerator = Accelerator(mixed_precision="fp16")
accelerator = Accelerator()

import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, ConcatDataset
from torchvision.transforms import v2 as T
from tqdm import tqdm
import time
from torchvision.io import read_image, ImageReadMode
import evaluate
from accelerate.utils import set_seed
from torchvision.ops import sigmoid_focal_loss
import random

seed = 42
set_seed(seed)
random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


def seed_worker(worker_id):
    worker_seed = seed
    random.seed(worker_seed)








def detect_environment():
    if "COLAB_GPU" in os.environ or "COLAB_TPU_ADDR" in os.environ:
        return "Colab"
    elif "KAGGLE_URL_BASE" in os.environ:
        return "Kaggle"
    else:
        return "Local"


def create_metrics():
    metrics = {
        "accuracy": evaluate.load("accuracy"),
        "precision": evaluate.load("precision"),
        "recall": evaluate.load("recall"),
        "f1": evaluate.load("f1"),
    }
    return metrics


def update_metrics(metrics, preds, labels):
    for metric in metrics.values():
        metric.add_batch(predictions=preds, references=labels)



def compute_metrics(metrics):
    results = {k: v.compute()[k] for k, v in metrics.items()}
    return results











class DDDSequenceDataset(Dataset):

    def __init__(self, root_dir, time_window_in_seconds, total_frames_in_window,
                 time_window_right_shift_by_seconds, transform):

        self.root_dir = root_dir
        self.time_window_in_seconds = time_window_in_seconds
        self.total_frames_in_window = total_frames_in_window
        self.time_window_right_shift_by_seconds = time_window_right_shift_by_seconds
        self.transform = transform

        self.total_positive = 0
        self.total_negative = 0
        self.sequence_frame_paths_and_labels = []
       
        self._sequence_processing()
        self.total_windows = len(self.sequence_frame_paths_and_labels)

        print(f"Total sequences: {self.total_windows}")
        print(f"Positive sequences: {self.total_positive}")
        print(f"Negative sequences: {self.total_negative}")


    def _sequence_processing(self):

        for subject in sorted(os.listdir(self.root_dir)):
            subject_path = os.path.join(self.root_dir, subject)

            if not os.path.isdir(subject_path):
                continue

            for scenario in sorted(os.listdir(subject_path)):
                video_path = os.path.join(subject_path, scenario)

                if not os.path.isdir(video_path):
                    continue

                frame_files = sorted(
                    f for f in os.listdir(video_path)
                    if f.lower().endswith(".jpg")
                )

                total_frames_in_video = len(frame_files)
                if total_frames_in_video == 0:
                    continue

                video_fps = 15 if scenario in ["night_noglasses", "night_glasses"] else 30

                window_frame_count = min(
                    total_frames_in_video,
                    int(video_fps * self.time_window_in_seconds)
                )

                video_stride = max(
                    1,
                    int(round(self.time_window_right_shift_by_seconds * video_fps))
                )

                total_windows_in_video = max(
                    1,
                    (total_frames_in_video - window_frame_count) // video_stride + 1
                )

                frame_time_interval = (
                    self.time_window_in_seconds /
                    self.total_frames_in_window
                )

                for window_index in range(total_windows_in_video):

                    frame_paths = []
                    frame_labels = []

                    for i in range(self.total_frames_in_window):

                        t = (
                            window_index * self.time_window_right_shift_by_seconds +
                            i * frame_time_interval
                        )

                        frame_index = min(
                            int(round(t * video_fps)),
                            total_frames_in_video - 1
                        )

                        fname = frame_files[frame_index]
                        frame_path = os.path.join(video_path, fname)

                        frame_paths.append(frame_path)

                        label = int(fname.rsplit("_", 1)[-1].split(".")[0])
                        frame_labels.append(label)

                    sequence_label = frame_labels[-1]

                    if sequence_label == 1:
                        self.total_positive += 1
                    else:
                        self.total_negative += 1

                    self.sequence_frame_paths_and_labels.append((frame_paths, sequence_label))

    def get_pos_weight(self):
        pos_weight = self.total_negative / max(self.total_positive, 1)
        return torch.tensor([pos_weight], dtype=torch.float32)


    def __len__(self):
        return self.total_windows


    def __getitem__(self, idx):

        frame_paths, label = self.sequence_frame_paths_and_labels[idx]
        images = []

        for path in frame_paths:
            img = read_image(path, mode=ImageReadMode.GRAY).float() / 255.0

            if self.transform:
                img = self.transform(img)

            images.append(img)

        images = torch.stack(images)  # (T, C, H, W)
        return images, torch.tensor(label, dtype=torch.float32)





    
    
class CNNEncoder(nn.Module):
    def __init__(self, *, encoder_feature_dim, dropout_encoder, model, weights):
        super().__init__()

        old_conv = model.features[0][0]
        model.features[0][0] = nn.Conv2d(in_channels=1, out_channels=old_conv.out_channels, 
                               kernel_size=old_conv.kernel_size, stride=old_conv.stride, padding=old_conv.padding, bias=False)

        with torch.no_grad():  
            model.features[0][0].weight.copy_(old_conv.weight.mean(dim=1, keepdim=True))

        self.features = model.features
        in_features = model.classifier[0].in_features

        self.spatial_attention = nn.Sequential(
            nn.Conv2d(in_features, in_features, kernel_size=1),
            nn.Sigmoid()
        )

        self.pool = nn.Sequential(
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten()
        )
                

        self.fc = nn.Sequential(
            nn.Linear(in_features, encoder_feature_dim),
            nn.LayerNorm(encoder_feature_dim),  
            nn.GELU(),
            nn.Dropout(dropout_encoder),
        )

        for param in self.features.parameters():
            param.requires_grad = False

        for param in self.features[-10:].parameters():
            param.requires_grad = True


    def forward(self, x):
        x = self.features(x)
        attn = self.spatial_attention(x)
        x = x * attn
        x = self.pool(x)
        x = self.fc(x)
        return x


class CausalTemporalConvBlock(nn.Module):

    def __init__(self, *, in_channels, out_channels, dilation,  dropout_temporal,  kernel_size = 3):
        super().__init__()

        self.padding = (kernel_size - 1) * dilation
        self.conv1 = nn.Conv1d(
            in_channels, out_channels, kernel_size, padding=self.padding, dilation=dilation)
        
        self.conv2 = nn.Conv1d(
            out_channels, out_channels, kernel_size, padding=self.padding, dilation=dilation)

        self.norm1 = nn.GroupNorm(num_groups=8, num_channels=out_channels)
        self.norm2 = nn.GroupNorm(num_groups=8, num_channels=out_channels)

        self.activation = nn.GELU()
        self.dropout = nn.Dropout(dropout_temporal)

        self.residual = (
            nn.Conv1d(in_channels, out_channels, 1) if in_channels != out_channels else nn.Identity())


    def forward(self, x):
        residual = self.residual(x)

        out = self.conv1(x)
        if self.padding > 0:
            out = out[:, :, :-self.padding]
        out = self.norm1(out)
        out = self.activation(out)
        out = self.dropout(out)

        out = self.conv2(out)
        if self.padding > 0:
            out = out[:, :, :-self.padding]
        out = self.norm2(out)
        out = self.activation(out)
        out = self.dropout(out)

        return self.activation(out + residual)



class CNNTemporalConv(nn.Module):
    def __init__(self, *, model, weights, encoder_feature_dim, dropout_encoder, dropout_temporal,
                 causal_one_output, causal_two_output, causal_three_output):
        super().__init__()

        self.encoder = CNNEncoder(model=model, weights=weights, encoder_feature_dim=encoder_feature_dim, dropout_encoder=dropout_encoder)
        
        self.temporal_attention = nn.Sequential(
            nn.Conv1d(causal_three_output, 1, kernel_size=1),
            nn.Softmax(dim=2))

        self.tcn = nn.Sequential(
            
            CausalTemporalConvBlock(in_channels=encoder_feature_dim, out_channels=causal_one_output,
                                    dropout_temporal=dropout_temporal, dilation=1),
            CausalTemporalConvBlock(in_channels=causal_one_output, out_channels=causal_two_output,
                                    dropout_temporal=dropout_temporal,   dilation=2),
            CausalTemporalConvBlock(in_channels=causal_two_output, out_channels=causal_three_output,
                                    dropout_temporal=dropout_temporal,  dilation=4),
            CausalTemporalConvBlock(in_channels=causal_three_output, out_channels=causal_three_output,
                                    dropout_temporal=dropout_temporal,   dilation=8),)

        self.classifier = nn.Linear(causal_three_output, 1)


    def forward(self, x):
        B, T, C, H, W = x.shape
        x = x.view(B * T, C, H, W)
        
        features = self.encoder(x)
        features = features.view(B, T, -1)
        features = features.transpose(1, 2)
        tcn_out = self.tcn(features)

        attn_weights = self.temporal_attention(tcn_out)
        pooled = (tcn_out * attn_weights).sum(dim=2)
        logits = self.classifier(pooled)
        return logits.squeeze(1)
     

from torchvision.models import mobilenet_v3_small, MobileNet_V3_Small_Weights
weights = MobileNet_V3_Small_Weights.DEFAULT
model = mobilenet_v3_small(weights=weights)

model = CNNTemporalConv(
    model=model,
    weights=weights,
    encoder_feature_dim=32,
    dropout_encoder=0.3,
    dropout_temporal=0.3,
    causal_one_output=32,
    causal_two_output=32,
    causal_three_output=32,
)

batch_size=32
time_window_in_seconds=8
total_frames_in_window=24
time_window_right_shift_by_seconds=5
encoder_backbone_lr, encoder_head_lr, temporal_lr = 1e-4, 1e-3, 1e-3



transform = T.Compose([
    T.RandomHorizontalFlip(),
    T.RandomRotation(degrees=10),
    T.RandomAffine(degrees=0, translate=(0.05, 0.05), scale=(0.95, 1.05)),
])

# /kaggle/input/datasets/manith04/ddd-processed-1-training-frames-type-1
# /kaggle/input/datasets/manith04/ddd-processed-2-training-frames-type-1
# /kaggle/input/datasets/manith04/ddd-processed-validation-frames-type-1


print("[HERE 0]")


train_dataset_1 = DDDSequenceDataset(root_dir="/kaggle/input/datasets/manith04/ddd-processed-1-training-frames-type-1", 
                                     time_window_in_seconds=time_window_in_seconds,
                                     total_frames_in_window=total_frames_in_window,
                                     time_window_right_shift_by_seconds=time_window_right_shift_by_seconds,
                                     transform=transform) 

train_dataset_2 = DDDSequenceDataset(root_dir="/kaggle/input/datasets/manith04/ddd-processed-2-training-frames-type-1",
                                     time_window_in_seconds=time_window_in_seconds,
                                     total_frames_in_window=total_frames_in_window,
                                     time_window_right_shift_by_seconds=time_window_right_shift_by_seconds,
                                     transform=transform) 

validation_dataset = DDDSequenceDataset(root_dir="/kaggle/input/datasets/manith04/ddd-processed-validation-frames-type-1", 
                                        time_window_in_seconds=time_window_in_seconds,
                                        total_frames_in_window=total_frames_in_window,
                                        time_window_right_shift_by_seconds=time_window_right_shift_by_seconds,
                                        transform=None) 


print("[HERE 1]")

cpu_count = os.cpu_count()

train_dataset = ConcatDataset([train_dataset_1, train_dataset_2])
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=cpu_count, pin_memory=True, 
                          persistent_workers=True, prefetch_factor=(6), in_order=True, worker_init_fn=seed_worker
) 
                   
val_loader = DataLoader(validation_dataset, batch_size=batch_size , shuffle=False, num_workers=cpu_count, pin_memory=True, 
                        persistent_workers=True, prefetch_factor=(6), in_order=True,  worker_init_fn=seed_worker)


print("[HERE 2]")



optimizer = torch.optim.AdamW([
    {"params": model.encoder.features.parameters(), "lr": encoder_backbone_lr},  
    {"params": model.encoder.fc.parameters(), "lr": encoder_head_lr},        
    {"params": model.tcn.parameters(), "lr": temporal_lr},
    {"params": model.temporal_attention.parameters(), "lr": temporal_lr},
    {"params": model.classifier.parameters(), "lr": temporal_lr},
], weight_decay=1e-4)


scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',           
    factor=0.5,           # multiply LR by 0.5 when triggered
    patience=5,           
    min_lr=1e-7          
)

print("[HERE 3]")

model, optimizer, train_loader, val_loader = accelerator.prepare(model, optimizer, train_loader, val_loader)
device = accelerator.device


total_positive = train_dataset_1.total_positive + train_dataset_2.total_positive
total_negative = train_dataset_1.total_negative + train_dataset_2.total_negative
pos_weight = torch.tensor(min(total_negative / max(total_positive, 1), 10.0),  # cap at 10
                            dtype=torch.float32,  device=device)

# criterion = sigmoid_focal_loss(alpha=alpha, gamma=2.0)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)


epochs = 120
checkpoint_dir = "checkpoint"
best_model_path = "best_model_new.pth"
log_file = "metrics_log.txt"
extra_path = os.path.join(checkpoint_dir, "extra_state.pt")

best_val_loss = float("inf")
resume_step, start_epoch = 0, 0


print("[HERE 4]")


if os.path.isdir(checkpoint_dir) and len(os.listdir(checkpoint_dir)) > 0:
    accelerator.print("🔄 Loading checkpoint...")
    accelerator.load_state(checkpoint_dir)

    if os.path.exists(extra_path):

        extra = torch.load(extra_path, map_location=device)
        start_epoch = extra.get("epoch", 0)
        best_val_loss = extra.get("best_val_loss", float("inf"))
        accelerator.print(f"Resuming from epoch {start_epoch}")

    else:
        accelerator.print("⚡ No extra_state.pt found, starting from scratch.")


if accelerator.is_main_process and start_epoch == 0:
    with open(log_file, "w") as file:
        file.write("epoch,train_loss,train_acc,train_precision,train_recall,train_f1,val_loss,val_acc,val_precision,val_recall,val_f1\n")

print("[HERE 5]")


for epoch in range(start_epoch, epochs):
    model.train()
    
    if accelerator.is_main_process:
        print(f"\nEpoch {epoch+1}/{epochs}")

    train_metrics = create_metrics()
    val_metrics = create_metrics()

    train_loss = 0
    train_bar =  tqdm(train_loader, desc="Training", disable=not accelerator.is_main_process)
    
    for frames, labels in train_bar:
        frames, labels = frames.to(device, non_blocking=True), labels.to(device, non_blocking=True)

        optimizer.zero_grad()
        outputs = model(frames)
        if torch.isnan(outputs).any():
            print("NaN right after forward pass")
            print(outputs.min(), outputs.max())

        
        outputs = outputs.clamp(-20, 20)

        #loss = sigmoid_focal_loss(inputs=outputs.squeeze(), targets=labels.float(), alpha=alpha, gamma=2.0, reduction='mean')
        loss = criterion(outputs, labels)
        accelerator.backward(loss)

        if torch.isnan(loss):
            print("LOSS NAN")
        
        if torch.isnan(outputs).any():
            print("OUTPUT NAN")
        

        if accelerator.sync_gradients:
            accelerator.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        train_loss += loss.item()
        preds = (torch.sigmoid(outputs) > 0.5).int()
        preds, labels = accelerator.gather_for_metrics((preds, labels.int()))

        update_metrics(train_metrics, preds, labels)

    train_results = compute_metrics(train_metrics)
    avg_train_loss = train_loss / len(train_loader)

    if accelerator.is_main_process:
        print(
            f"Epoch {epoch+1} - "
            f"Train Loss: {avg_train_loss:.4f} | "
            f"Acc: {train_results['accuracy']:.4f} | "
            f"Precision: {train_results['precision']:.4f} | "
            f"Recall: {train_results['recall']:.4f} | "
            f"F1: {train_results['f1']:.4f}"
        )

    model.eval()
    val_loss = 0
    
    with torch.no_grad():
        val_bar = tqdm(val_loader, desc="Validation", disable=not accelerator.is_main_process)
        
        for frames, labels in val_bar:    
            frames, labels = frames.to(device, non_blocking=True), labels.to(device, non_blocking=True)
            outputs = model(frames)
            loss = criterion(outputs, labels)

            val_loss += loss.item()
            preds = (torch.sigmoid(outputs) > 0.5).int()
            preds, labels = accelerator.gather_for_metrics((preds, labels.int()))

            update_metrics(val_metrics, preds, labels)

    val_results = compute_metrics(val_metrics)
    avg_val_loss = val_loss / len(val_loader)
    scheduler.step(val_results["accuracy"])  # scheduler updated based on val accuracy

    if accelerator.is_main_process:
        print(
            f"Epoch {epoch+1} - "
            f"Val Loss: {avg_val_loss:.4f} | "
            f"Acc: {val_results['accuracy']:.4f} | "
            f"Precision: {val_results['precision']:.4f} | "
            f"Recall: {val_results['recall']:.4f} | "
            f"F1: {val_results['f1']:.4f}"
        )

        with open(log_file, "a") as f:
            f.write(
                f"{epoch+1},{avg_train_loss:.3f},{train_results['accuracy']:.3f},"
                f"{train_results['precision']:.3f},{train_results['recall']:.3f},{train_results['f1']:.3f},"
                f"{avg_val_loss:.3f},{val_results['accuracy']:.3f},{val_results['precision']:.3f},"
                f"{val_results['recall']:.3f},{val_results['f1']:.3f}\n"
            )

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            unwrapped_model = accelerator.unwrap_model(model)
            torch.save(unwrapped_model.state_dict(), best_model_path)
            print("⭐ Best model updated!")

        accelerator.save_state(checkpoint_dir)
        torch.save({"epoch": epoch + 1, "best_val_loss": best_val_loss}, extra_path)
# Out:
# Writing model.py

# %%
# !rm -rf /kaggle/working
# Out:
# rm: cannot remove '/kaggle/working': Device or resource busy

# %%
# !uv pip install evaluate -q
# !accelerate launch model.py --num_processes=2
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `2`
# 		More than one GPU was found, enabling multi-GPU training.
# 		If this was unintended please pass in `--num_processes=1`.
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# [HERE 0]
# [HERE 0]
# Total sequences: 2879
# Positive sequences: 1674
# Negative sequences: 1205
# Total sequences: 2879
# Positive sequences: 1674
# Negative sequences: 1205
# Total sequences: 2406
# Positive sequences: 1447
# Negative sequences: 959
# Total sequences: 2406
# Positive sequences: 1447
# Negative sequences: 959
# Total sequences: 1133
# Positive sequences: 608
# Negative sequences: 525
# [HERE 1]
# Total sequences: 1133
# Positive sequences: 608
# Negative sequences: 525
# [HERE 1]
# [HERE 2]
# [HERE 2]
# [HERE 3]
# [HERE 3]
# [HERE 4]
# [HERE 5]
# [HERE 4]
# [HERE 5]
#
# Epoch 1/120
# Training: 100%|█████████████████████████████████| 83/83 [02:59<00:00,  2.16s/it]
# Epoch 1 - Train Loss: 0.5052 | Acc: 0.6411 | Precision: 0.7147 | Recall: 0.6527 | F1: 0.6823
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.51it/s]
# Epoch 1 - Val Loss: 1.1094 | Acc: 0.4854 | Precision: 0.5415 | Recall: 0.2681 | F1: 0.3586
# ⭐ Best model updated!
#
# Epoch 2/120
# Training: 100%|█████████████████████████████████| 83/83 [03:04<00:00,  2.23s/it]
# Epoch 2 - Train Loss: 0.3667 | Acc: 0.8204 | Precision: 0.8008 | Recall: 0.9263 | F1: 0.8590
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.55it/s]
# Epoch 2 - Val Loss: 1.3237 | Acc: 0.4704 | Precision: 0.5116 | Recall: 0.2911 | F1: 0.3711
#
# Epoch 3/120
# Training: 100%|█████████████████████████████████| 83/83 [03:01<00:00,  2.19s/it]
# Epoch 3 - Train Loss: 0.3015 | Acc: 0.8518 | Precision: 0.8402 | Recall: 0.9250 | F1: 0.8806
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.59it/s]
# Epoch 3 - Val Loss: 1.2901 | Acc: 0.5278 | Precision: 0.5901 | Recall: 0.3931 | F1: 0.4719
#
# Epoch 4/120
# Training: 100%|█████████████████████████████████| 83/83 [02:58<00:00,  2.15s/it]
# Epoch 4 - Train Loss: 0.2599 | Acc: 0.8641 | Precision: 0.8620 | Recall: 0.9167 | F1: 0.8885
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.59it/s]
# Epoch 4 - Val Loss: 1.4465 | Acc: 0.5516 | Precision: 0.5794 | Recall: 0.6003 | F1: 0.5897
#
# Epoch 5/120
# Training: 100%|█████████████████████████████████| 83/83 [03:04<00:00,  2.22s/it]
# Epoch 5 - Train Loss: 0.2459 | Acc: 0.8783 | Precision: 0.8810 | Recall: 0.9180 | F1: 0.8991
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.52it/s]
# Epoch 5 - Val Loss: 1.5063 | Acc: 0.5675 | Precision: 0.5716 | Recall: 0.7747 | F1: 0.6578
#
# Epoch 6/120
# Training: 100%|█████████████████████████████████| 83/83 [03:04<00:00,  2.22s/it]
# Epoch 6 - Train Loss: 0.2184 | Acc: 0.8918 | Precision: 0.8930 | Recall: 0.9279 | F1: 0.9101
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.62it/s]
# Epoch 6 - Val Loss: 1.7004 | Acc: 0.5578 | Precision: 0.5663 | Recall: 0.7516 | F1: 0.6459
#
# Epoch 7/120
# Training: 100%|█████████████████████████████████| 83/83 [02:59<00:00,  2.17s/it]
# Epoch 7 - Train Loss: 0.2159 | Acc: 0.9001 | Precision: 0.9030 | Recall: 0.9308 | F1: 0.9167
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.56it/s]
# Epoch 7 - Val Loss: 1.2312 | Acc: 0.6028 | Precision: 0.6148 | Recall: 0.6957 | F1: 0.6528
#
# Epoch 8/120
# Training: 100%|█████████████████████████████████| 83/83 [03:02<00:00,  2.20s/it]
# Epoch 8 - Train Loss: 0.1967 | Acc: 0.9092 | Precision: 0.9136 | Recall: 0.9346 | F1: 0.9240
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.60it/s]
# Epoch 8 - Val Loss: 1.1514 | Acc: 0.6346 | Precision: 0.6370 | Recall: 0.7418 | F1: 0.6854
#
# Epoch 9/120
# Training: 100%|█████████████████████████████████| 83/83 [03:11<00:00,  2.31s/it]
# Epoch 9 - Train Loss: 0.1739 | Acc: 0.9096 | Precision: 0.9154 | Recall: 0.9330 | F1: 0.9242
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.53it/s]
# Epoch 9 - Val Loss: 1.0697 | Acc: 0.6558 | Precision: 0.6430 | Recall: 0.8059 | F1: 0.7153
# ⭐ Best model updated!
#
# Epoch 10/120
# Training: 100%|█████████████████████████████████| 83/83 [03:00<00:00,  2.18s/it]
# Epoch 10 - Train Loss: 0.1837 | Acc: 0.9150 | Precision: 0.9185 | Recall: 0.9394 | F1: 0.9289
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.58it/s]
# Epoch 10 - Val Loss: 1.0152 | Acc: 0.6646 | Precision: 0.6681 | Recall: 0.7451 | F1: 0.7045
# ⭐ Best model updated!
#
# Epoch 11/120
# Training: 100%|█████████████████████████████████| 83/83 [03:03<00:00,  2.21s/it]
# Epoch 11 - Train Loss: 0.1700 | Acc: 0.9137 | Precision: 0.9229 | Recall: 0.9318 | F1: 0.9273
# Validation: 100%|███████████████████████████████| 18/18 [00:12<00:00,  1.47it/s]
# Epoch 11 - Val Loss: 0.9469 | Acc: 0.6734 | Precision: 0.6657 | Recall: 0.7862 | F1: 0.7210
# ⭐ Best model updated!
#
# Epoch 12/120
# Training: 100%|█████████████████████████████████| 83/83 [03:00<00:00,  2.17s/it]
# Epoch 12 - Train Loss: 0.1563 | Acc: 0.9209 | Precision: 0.9319 | Recall: 0.9343 | F1: 0.9331
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.51it/s]
# Epoch 12 - Val Loss: 0.6749 | Acc: 0.7079 | Precision: 0.7978 | Recall: 0.6102 | F1: 0.6915
# ⭐ Best model updated!
#
# Epoch 13/120
# Training: 100%|█████████████████████████████████| 83/83 [03:03<00:00,  2.20s/it]
# Epoch 13 - Train Loss: 0.1464 | Acc: 0.9253 | Precision: 0.9332 | Recall: 0.9407 | F1: 0.9370
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.50it/s]
# Epoch 13 - Val Loss: 0.6499 | Acc: 0.7220 | Precision: 0.7890 | Recall: 0.6579 | F1: 0.7175
# ⭐ Best model updated!
#
# Epoch 14/120
# Training: 100%|█████████████████████████████████| 83/83 [03:04<00:00,  2.22s/it]
# Epoch 14 - Train Loss: 0.1530 | Acc: 0.9215 | Precision: 0.9328 | Recall: 0.9343 | F1: 0.9336
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.61it/s]
# Epoch 14 - Val Loss: 0.6587 | Acc: 0.7184 | Precision: 0.8121 | Recall: 0.6184 | F1: 0.7021
#
# Epoch 15/120
# Training: 100%|█████████████████████████████████| 83/83 [03:03<00:00,  2.21s/it]
# Epoch 15 - Train Loss: 0.1379 | Acc: 0.9304 | Precision: 0.9405 | Recall: 0.9417 | F1: 0.9411
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.62it/s]
# Epoch 15 - Val Loss: 0.8443 | Acc: 0.7008 | Precision: 0.7307 | Recall: 0.7007 | F1: 0.7154
#
# Epoch 16/120
# Training: 100%|█████████████████████████████████| 83/83 [02:59<00:00,  2.17s/it]
# Epoch 16 - Train Loss: 0.1383 | Acc: 0.9273 | Precision: 0.9374 | Recall: 0.9398 | F1: 0.9386
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.59it/s]
# Epoch 16 - Val Loss: 0.7162 | Acc: 0.7008 | Precision: 0.7762 | Recall: 0.6217 | F1: 0.6904
#
# Epoch 17/120
# Training: 100%|█████████████████████████████████| 83/83 [02:57<00:00,  2.14s/it]
# Epoch 17 - Train Loss: 0.1326 | Acc: 0.9364 | Precision: 0.9456 | Recall: 0.9468 | F1: 0.9462
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.63it/s]
# Epoch 17 - Val Loss: 0.8614 | Acc: 0.7061 | Precision: 0.7477 | Recall: 0.6826 | F1: 0.7137
#
# Epoch 18/120
# Training: 100%|█████████████████████████████████| 83/83 [02:57<00:00,  2.14s/it]
# Epoch 18 - Train Loss: 0.1458 | Acc: 0.9328 | Precision: 0.9413 | Recall: 0.9452 | F1: 0.9432
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.56it/s]
# Epoch 18 - Val Loss: 0.6673 | Acc: 0.7405 | Precision: 0.8398 | Recall: 0.6382 | F1: 0.7252
#
# Epoch 19/120
# Training: 100%|█████████████████████████████████| 83/83 [03:02<00:00,  2.20s/it]
# Epoch 19 - Train Loss: 0.1224 | Acc: 0.9389 | Precision: 0.9461 | Recall: 0.9507 | F1: 0.9484
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.62it/s]
# Epoch 19 - Val Loss: 0.7999 | Acc: 0.7273 | Precision: 0.7455 | Recall: 0.7467 | F1: 0.7461
#
# Epoch 20/120
# Training: 100%|█████████████████████████████████| 83/83 [03:03<00:00,  2.21s/it]
# Epoch 20 - Train Loss: 0.1248 | Acc: 0.9385 | Precision: 0.9487 | Recall: 0.9471 | F1: 0.9479
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.62it/s]
# Epoch 20 - Val Loss: 0.7000 | Acc: 0.7229 | Precision: 0.7722 | Recall: 0.6859 | F1: 0.7265
#
# Epoch 21/120
# Training: 100%|█████████████████████████████████| 83/83 [02:59<00:00,  2.16s/it]
# Epoch 21 - Train Loss: 0.1293 | Acc: 0.9389 | Precision: 0.9510 | Recall: 0.9452 | F1: 0.9481
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.65it/s]
# Epoch 21 - Val Loss: 0.7930 | Acc: 0.7123 | Precision: 0.7592 | Recall: 0.6793 | F1: 0.7170
#
# Epoch 22/120
# Training: 100%|█████████████████████████████████| 83/83 [03:02<00:00,  2.20s/it]
# Epoch 22 - Train Loss: 0.1094 | Acc: 0.9455 | Precision: 0.9542 | Recall: 0.9535 | F1: 0.9538
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.62it/s]
# Epoch 22 - Val Loss: 0.7855 | Acc: 0.7061 | Precision: 0.7391 | Recall: 0.6990 | F1: 0.7185
#
# Epoch 23/120
# Training: 100%|█████████████████████████████████| 83/83 [03:02<00:00,  2.19s/it]
# Epoch 23 - Train Loss: 0.1158 | Acc: 0.9451 | Precision: 0.9553 | Recall: 0.9516 | F1: 0.9535
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.62it/s]
# Epoch 23 - Val Loss: 0.9255 | Acc: 0.6929 | Precision: 0.7355 | Recall: 0.6678 | F1: 0.7000
#
# Epoch 24/120
# Training: 100%|█████████████████████████████████| 83/83 [02:59<00:00,  2.16s/it]
# Epoch 24 - Train Loss: 0.1141 | Acc: 0.9425 | Precision: 0.9530 | Recall: 0.9494 | F1: 0.9512
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.61it/s]
# Epoch 24 - Val Loss: 1.0657 | Acc: 0.6770 | Precision: 0.6822 | Recall: 0.7451 | F1: 0.7123
#
# Epoch 25/120
# Training: 100%|█████████████████████████████████| 83/83 [03:04<00:00,  2.22s/it]
# Epoch 25 - Train Loss: 0.1063 | Acc: 0.9510 | Precision: 0.9587 | Recall: 0.9583 | F1: 0.9585
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.60it/s]
# Epoch 25 - Val Loss: 1.1590 | Acc: 0.6964 | Precision: 0.6870 | Recall: 0.7977 | F1: 0.7382
#
# Epoch 26/120
# Training: 100%|█████████████████████████████████| 83/83 [03:03<00:00,  2.21s/it]
# Epoch 26 - Train Loss: 0.0986 | Acc: 0.9529 | Precision: 0.9606 | Recall: 0.9596 | F1: 0.9601
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.63it/s]
# Epoch 26 - Val Loss: 1.1026 | Acc: 0.6973 | Precision: 0.7154 | Recall: 0.7237 | F1: 0.7195
#
# Epoch 27/120
# Training: 100%|█████████████████████████████████| 83/83 [03:02<00:00,  2.20s/it]
# Epoch 27 - Train Loss: 0.0894 | Acc: 0.9548 | Precision: 0.9648 | Recall: 0.9583 | F1: 0.9616
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.58it/s]
# Epoch 27 - Val Loss: 1.1208 | Acc: 0.6990 | Precision: 0.7038 | Recall: 0.7582 | F1: 0.7300
#
# Epoch 28/120
# Training: 100%|█████████████████████████████████| 83/83 [03:00<00:00,  2.18s/it]
# Epoch 28 - Train Loss: 0.0943 | Acc: 0.9561 | Precision: 0.9640 | Recall: 0.9616 | F1: 0.9628
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.59it/s]
# Epoch 28 - Val Loss: 0.9309 | Acc: 0.7290 | Precision: 0.7529 | Recall: 0.7368 | F1: 0.7448
#
# Epoch 29/120
# Training: 100%|█████████████████████████████████| 83/83 [03:04<00:00,  2.22s/it]
# Epoch 29 - Train Loss: 0.0976 | Acc: 0.9561 | Precision: 0.9631 | Recall: 0.9625 | F1: 0.9628
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.59it/s]
# Epoch 29 - Val Loss: 1.0338 | Acc: 0.7255 | Precision: 0.7361 | Recall: 0.7615 | F1: 0.7486
#
# Epoch 30/120
# Training: 100%|█████████████████████████████████| 83/83 [03:02<00:00,  2.20s/it]
# Epoch 30 - Train Loss: 0.0911 | Acc: 0.9605 | Precision: 0.9685 | Recall: 0.9644 | F1: 0.9664
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.59it/s]
# Epoch 30 - Val Loss: 0.9889 | Acc: 0.7211 | Precision: 0.7433 | Recall: 0.7336 | F1: 0.7384
#
# Epoch 31/120
# Training: 100%|█████████████████████████████████| 83/83 [03:01<00:00,  2.19s/it]
# Epoch 31 - Train Loss: 0.0830 | Acc: 0.9601 | Precision: 0.9640 | Recall: 0.9686 | F1: 0.9663
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.57it/s]
# Epoch 31 - Val Loss: 0.8936 | Acc: 0.7352 | Precision: 0.7780 | Recall: 0.7089 | F1: 0.7418
#
# Epoch 32/120
# Training: 100%|█████████████████████████████████| 83/83 [03:04<00:00,  2.22s/it]
# Epoch 32 - Train Loss: 0.0743 | Acc: 0.9618 | Precision: 0.9710 | Recall: 0.9641 | F1: 0.9675
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.65it/s]
# Epoch 32 - Val Loss: 0.9576 | Acc: 0.7202 | Precision: 0.7479 | Recall: 0.7220 | F1: 0.7347
#
# Epoch 33/120
# Training: 100%|█████████████████████████████████| 83/83 [03:01<00:00,  2.18s/it]
# Epoch 33 - Train Loss: 0.0852 | Acc: 0.9610 | Precision: 0.9679 | Recall: 0.9660 | F1: 0.9670
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.61it/s]
# Epoch 33 - Val Loss: 0.8269 | Acc: 0.7326 | Precision: 0.7850 | Recall: 0.6908 | F1: 0.7349
#
# Epoch 34/120
# Training: 100%|█████████████████████████████████| 83/83 [03:00<00:00,  2.18s/it]
# Epoch 34 - Train Loss: 0.0656 | Acc: 0.9650 | Precision: 0.9696 | Recall: 0.9712 | F1: 0.9704
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.63it/s]
# Epoch 34 - Val Loss: 0.9061 | Acc: 0.7282 | Precision: 0.7717 | Recall: 0.7007 | F1: 0.7345
#
# Epoch 35/120
# Training: 100%|█████████████████████████████████| 83/83 [03:00<00:00,  2.18s/it]
# Epoch 35 - Train Loss: 0.0725 | Acc: 0.9644 | Precision: 0.9702 | Recall: 0.9696 | F1: 0.9699
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.64it/s]
# Epoch 35 - Val Loss: 0.9981 | Acc: 0.7158 | Precision: 0.7466 | Recall: 0.7122 | F1: 0.7290
#
# Epoch 36/120
# Training: 100%|█████████████████████████████████| 83/83 [03:00<00:00,  2.17s/it]
# Epoch 36 - Train Loss: 0.0746 | Acc: 0.9627 | Precision: 0.9722 | Recall: 0.9644 | F1: 0.9683
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.66it/s]
# Epoch 36 - Val Loss: 0.8953 | Acc: 0.7299 | Precision: 0.7677 | Recall: 0.7122 | F1: 0.7389
#
# Epoch 37/120
# Training: 100%|█████████████████████████████████| 83/83 [03:01<00:00,  2.18s/it]
# Epoch 37 - Train Loss: 0.0761 | Acc: 0.9659 | Precision: 0.9697 | Recall: 0.9728 | F1: 0.9712
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.62it/s]
# Epoch 37 - Val Loss: 0.8932 | Acc: 0.7202 | Precision: 0.7740 | Recall: 0.6760 | F1: 0.7217
#
# Epoch 38/120
# Training: 100%|█████████████████████████████████| 83/83 [03:04<00:00,  2.22s/it]
# Epoch 38 - Train Loss: 0.0744 | Acc: 0.9622 | Precision: 0.9737 | Recall: 0.9619 | F1: 0.9678
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.63it/s]
# Epoch 38 - Val Loss: 1.0394 | Acc: 0.7202 | Precision: 0.7429 | Recall: 0.7319 | F1: 0.7374
#
# Epoch 39/120
# Training: 100%|█████████████████████████████████| 83/83 [02:59<00:00,  2.17s/it]
# Epoch 39 - Train Loss: 0.0731 | Acc: 0.9686 | Precision: 0.9758 | Recall: 0.9708 | F1: 0.9733
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.65it/s]
# Epoch 39 - Val Loss: 0.9246 | Acc: 0.7264 | Precision: 0.7844 | Recall: 0.6760 | F1: 0.7261
#
# Epoch 40/120
# Training: 100%|█████████████████████████████████| 83/83 [02:58<00:00,  2.15s/it]
# Epoch 40 - Train Loss: 0.0719 | Acc: 0.9680 | Precision: 0.9707 | Recall: 0.9753 | F1: 0.9730
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.55it/s]
# Epoch 40 - Val Loss: 0.9369 | Acc: 0.7290 | Precision: 0.7722 | Recall: 0.7023 | F1: 0.7356
#
# Epoch 41/120
# Training: 100%|█████████████████████████████████| 83/83 [02:59<00:00,  2.17s/it]
# Epoch 41 - Train Loss: 0.0741 | Acc: 0.9678 | Precision: 0.9731 | Recall: 0.9724 | F1: 0.9728
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.60it/s]
# Epoch 41 - Val Loss: 0.9799 | Acc: 0.7246 | Precision: 0.7731 | Recall: 0.6891 | F1: 0.7287
#
# Epoch 42/120
# Training: 100%|█████████████████████████████████| 83/83 [02:58<00:00,  2.15s/it]
# Epoch 42 - Train Loss: 0.0622 | Acc: 0.9652 | Precision: 0.9711 | Recall: 0.9699 | F1: 0.9705
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.63it/s]
# Epoch 42 - Val Loss: 1.0331 | Acc: 0.7193 | Precision: 0.7458 | Recall: 0.7237 | F1: 0.7346
#
# Epoch 43/120
# Training: 100%|█████████████████████████████████| 83/83 [02:59<00:00,  2.17s/it]
# Epoch 43 - Train Loss: 0.0618 | Acc: 0.9690 | Precision: 0.9752 | Recall: 0.9721 | F1: 0.9737
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.63it/s]
# Epoch 43 - Val Loss: 1.0163 | Acc: 0.7167 | Precision: 0.7513 | Recall: 0.7056 | F1: 0.7277
#
# Epoch 44/120
# Training: 100%|█████████████████████████████████| 83/83 [03:05<00:00,  2.23s/it]
# Epoch 44 - Train Loss: 0.0607 | Acc: 0.9707 | Precision: 0.9778 | Recall: 0.9724 | F1: 0.9751
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.62it/s]
# Epoch 44 - Val Loss: 1.0702 | Acc: 0.7140 | Precision: 0.7457 | Recall: 0.7089 | F1: 0.7268
#
# Epoch 45/120
# Training: 100%|█████████████████████████████████| 83/83 [02:57<00:00,  2.14s/it]
# Epoch 45 - Train Loss: 0.0659 | Acc: 0.9680 | Precision: 0.9746 | Recall: 0.9712 | F1: 0.9729
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.63it/s]
# Epoch 45 - Val Loss: 1.1008 | Acc: 0.7202 | Precision: 0.7470 | Recall: 0.7237 | F1: 0.7352
#
# Epoch 46/120
# Training: 100%|█████████████████████████████████| 83/83 [03:00<00:00,  2.18s/it]
# Epoch 46 - Train Loss: 0.0645 | Acc: 0.9673 | Precision: 0.9721 | Recall: 0.9724 | F1: 0.9723
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.57it/s]
# Epoch 46 - Val Loss: 0.9957 | Acc: 0.7255 | Precision: 0.7776 | Recall: 0.6842 | F1: 0.7279
#
# Epoch 47/120
# Training: 100%|█████████████████████████████████| 83/83 [03:04<00:00,  2.22s/it]
# Epoch 47 - Train Loss: 0.0730 | Acc: 0.9665 | Precision: 0.9715 | Recall: 0.9718 | F1: 0.9716
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.61it/s]
# Epoch 47 - Val Loss: 1.0310 | Acc: 0.7193 | Precision: 0.7608 | Recall: 0.6957 | F1: 0.7268
#
# Epoch 48/120
# Training: 100%|█████████████████████████████████| 83/83 [03:01<00:00,  2.19s/it]
# Epoch 48 - Train Loss: 0.0638 | Acc: 0.9693 | Precision: 0.9768 | Recall: 0.9712 | F1: 0.9740
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.60it/s]
# Epoch 48 - Val Loss: 1.0707 | Acc: 0.7158 | Precision: 0.7527 | Recall: 0.7007 | F1: 0.7257
#
# Epoch 49/120
# Training: 100%|█████████████████████████████████| 83/83 [03:01<00:00,  2.19s/it]
# Epoch 49 - Train Loss: 0.0705 | Acc: 0.9642 | Precision: 0.9705 | Recall: 0.9689 | F1: 0.9697
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.61it/s]
# Epoch 49 - Val Loss: 1.0171 | Acc: 0.7220 | Precision: 0.7649 | Recall: 0.6957 | F1: 0.7287
#
# Epoch 50/120
# Training: 100%|█████████████████████████████████| 83/83 [03:05<00:00,  2.24s/it]
# Epoch 50 - Train Loss: 0.0593 | Acc: 0.9688 | Precision: 0.9774 | Recall: 0.9696 | F1: 0.9735
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.62it/s]
# Epoch 50 - Val Loss: 1.0714 | Acc: 0.7184 | Precision: 0.7522 | Recall: 0.7089 | F1: 0.7299
#
# Epoch 51/120
# Training: 100%|█████████████████████████████████| 83/83 [03:01<00:00,  2.18s/it]
# Epoch 51 - Train Loss: 0.0682 | Acc: 0.9680 | Precision: 0.9716 | Recall: 0.9744 | F1: 0.9730
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.60it/s]
# Epoch 51 - Val Loss: 1.0626 | Acc: 0.7167 | Precision: 0.7504 | Recall: 0.7072 | F1: 0.7282
#
# Epoch 52/120
# Training: 100%|█████████████████████████████████| 83/83 [03:04<00:00,  2.22s/it]
# Epoch 52 - Train Loss: 0.0613 | Acc: 0.9720 | Precision: 0.9778 | Recall: 0.9747 | F1: 0.9763
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.61it/s]
# Epoch 52 - Val Loss: 1.0729 | Acc: 0.7176 | Precision: 0.7535 | Recall: 0.7039 | F1: 0.7279
#
# Epoch 53/120
# Training: 100%|█████████████████████████████████| 83/83 [03:00<00:00,  2.18s/it]
# Epoch 53 - Train Loss: 0.0612 | Acc: 0.9671 | Precision: 0.9746 | Recall: 0.9696 | F1: 0.9721
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.59it/s]
# Epoch 53 - Val Loss: 1.1030 | Acc: 0.7140 | Precision: 0.7483 | Recall: 0.7039 | F1: 0.7254
#
# Epoch 54/120
# Training: 100%|█████████████████████████████████| 83/83 [03:00<00:00,  2.17s/it]
# Epoch 54 - Train Loss: 0.0627 | Acc: 0.9705 | Precision: 0.9762 | Recall: 0.9737 | F1: 0.9750
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.54it/s]
# Epoch 54 - Val Loss: 1.1570 | Acc: 0.7123 | Precision: 0.7398 | Recall: 0.7155 | F1: 0.7274
#
# Epoch 55/120
# Training: 100%|█████████████████████████████████| 83/83 [03:05<00:00,  2.24s/it]
# Epoch 55 - Train Loss: 0.0658 | Acc: 0.9716 | Precision: 0.9748 | Recall: 0.9773 | F1: 0.9760
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.58it/s]
# Epoch 55 - Val Loss: 1.0845 | Acc: 0.7176 | Precision: 0.7553 | Recall: 0.7007 | F1: 0.7270
#
# Epoch 56/120
# Training: 100%|█████████████████████████████████| 83/83 [03:01<00:00,  2.19s/it]
# Epoch 56 - Train Loss: 0.0551 | Acc: 0.9726 | Precision: 0.9778 | Recall: 0.9756 | F1: 0.9767
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.54it/s]
# Epoch 56 - Val Loss: 1.0644 | Acc: 0.7184 | Precision: 0.7576 | Recall: 0.6990 | F1: 0.7271
#
# Epoch 57/120
# Training: 100%|█████████████████████████████████| 83/83 [03:53<00:00,  2.82s/it]
# Epoch 57 - Train Loss: 0.0704 | Acc: 0.9692 | Precision: 0.9753 | Recall: 0.9724 | F1: 0.9738
# Validation: 100%|███████████████████████████████| 18/18 [00:12<00:00,  1.47it/s]
# Epoch 57 - Val Loss: 1.0641 | Acc: 0.7211 | Precision: 0.7607 | Recall: 0.7007 | F1: 0.7295
#
# Epoch 58/120
# Training: 100%|█████████████████████████████████| 83/83 [03:00<00:00,  2.17s/it]
# Epoch 58 - Train Loss: 0.0610 | Acc: 0.9714 | Precision: 0.9793 | Recall: 0.9721 | F1: 0.9757
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.62it/s]
# Epoch 58 - Val Loss: 1.0703 | Acc: 0.7202 | Precision: 0.7594 | Recall: 0.7007 | F1: 0.7288
#
# Epoch 59/120
# Training: 100%|█████████████████████████████████| 83/83 [03:04<00:00,  2.22s/it]
# Epoch 59 - Train Loss: 0.0595 | Acc: 0.9703 | Precision: 0.9753 | Recall: 0.9744 | F1: 0.9748
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.61it/s]
# Epoch 59 - Val Loss: 1.0852 | Acc: 0.7176 | Precision: 0.7553 | Recall: 0.7007 | F1: 0.7270
#
# Epoch 60/120
# Training: 100%|█████████████████████████████████| 83/83 [03:00<00:00,  2.18s/it]
# Epoch 60 - Train Loss: 0.0641 | Acc: 0.9726 | Precision: 0.9781 | Recall: 0.9753 | F1: 0.9767
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.58it/s]
# Epoch 60 - Val Loss: 1.1070 | Acc: 0.7176 | Precision: 0.7535 | Recall: 0.7039 | F1: 0.7279
#
# Epoch 61/120
# Training: 100%|█████████████████████████████████| 83/83 [03:05<00:00,  2.24s/it]
# Epoch 61 - Train Loss: 0.0611 | Acc: 0.9720 | Precision: 0.9760 | Recall: 0.9766 | F1: 0.9763
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.59it/s]
# Epoch 61 - Val Loss: 1.1185 | Acc: 0.7167 | Precision: 0.7513 | Recall: 0.7056 | F1: 0.7277
#
# Epoch 62/120

# %%
# !uv pip install evaluate -q
# !accelerate launch model.py --num_processes=2 --mixed_precision=fp16
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `2`
# 		More than one GPU was found, enabling multi-GPU training.
# 		If this was unintended please pass in `--num_processes=1`.
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# [HERE 0]
# [HERE 0]
# Total sequences: 2879
# Positive sequences: 1674
# Negative sequences: 1205
# Total sequences: 2879
# Positive sequences: 1674
# Negative sequences: 1205
# Total sequences: 2406
# Positive sequences: 1447
# Negative sequences: 959
# Total sequences: 2406
# Positive sequences: 1447
# Negative sequences: 959
# Total sequences: 1133
# Positive sequences: 608
# Negative sequences: 525
# [HERE 1]
# [HERE 2]
# Total sequences: 1133
# Positive sequences: 608
# Negative sequences: 525
# [HERE 1]
# [HERE 2]
# [HERE 3]
# [HERE 3]
# [HERE 4]
# [HERE 5]
# [HERE 4]
# [HERE 5]
#
# Epoch 1/120
# Training: 100%|█████████████████████████████████| 83/83 [03:04<00:00,  2.22s/it]
# Epoch 1 - Train Loss: 0.4891 | Acc: 0.6658 | Precision: 0.7296 | Recall: 0.6898 | F1: 0.7092
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.54it/s]
# Epoch 1 - Val Loss: 1.0321 | Acc: 0.4545 | Precision: 0.4892 | Recall: 0.3734 | F1: 0.4235
# ⭐ Best model updated!
#
# Epoch 2/120
# Training: 100%|█████████████████████████████████| 83/83 [02:56<00:00,  2.12s/it]
# Epoch 2 - Train Loss: 0.3633 | Acc: 0.8165 | Precision: 0.8048 | Recall: 0.9100 | F1: 0.8541
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.57it/s]
# Epoch 2 - Val Loss: 1.1696 | Acc: 0.4943 | Precision: 0.5368 | Recall: 0.4194 | F1: 0.4709
#
# Epoch 3/120
# Training: 100%|█████████████████████████████████| 83/83 [02:57<00:00,  2.13s/it]
# Epoch 3 - Train Loss: 0.3164 | Acc: 0.8352 | Precision: 0.8344 | Recall: 0.8994 | F1: 0.8657
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.54it/s]
# Epoch 3 - Val Loss: 1.1509 | Acc: 0.5260 | Precision: 0.5773 | Recall: 0.4359 | F1: 0.4967
#
# Epoch 4/120
# Training: 100%|█████████████████████████████████| 83/83 [03:00<00:00,  2.18s/it]
# Epoch 4 - Train Loss: 0.2815 | Acc: 0.8500 | Precision: 0.8575 | Recall: 0.8946 | F1: 0.8756
# Validation: 100%|███████████████████████████████| 18/18 [00:12<00:00,  1.49it/s]
# Epoch 4 - Val Loss: 1.1588 | Acc: 0.5578 | Precision: 0.5732 | Recall: 0.6891 | F1: 0.6258
#
# Epoch 5/120
# Training: 100%|█████████████████████████████████| 83/83 [02:55<00:00,  2.12s/it]
# Epoch 5 - Train Loss: 0.2591 | Acc: 0.8746 | Precision: 0.8786 | Recall: 0.9138 | F1: 0.8959
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.58it/s]
# Epoch 5 - Val Loss: 1.6770 | Acc: 0.5534 | Precision: 0.5606 | Recall: 0.7763 | F1: 0.6510
#
# Epoch 6/120
# Training: 100%|█████████████████████████████████| 83/83 [02:54<00:00,  2.10s/it]
# Epoch 6 - Train Loss: 0.2373 | Acc: 0.8827 | Precision: 0.8873 | Recall: 0.9180 | F1: 0.9024
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.61it/s]
# Epoch 6 - Val Loss: 1.5691 | Acc: 0.5331 | Precision: 0.5508 | Recall: 0.7039 | F1: 0.6181
#
# Epoch 7/120
# Training: 100%|█████████████████████████████████| 83/83 [02:56<00:00,  2.12s/it]
# Epoch 7 - Train Loss: 0.2233 | Acc: 0.8910 | Precision: 0.8970 | Recall: 0.9212 | F1: 0.9089
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.63it/s]
# Epoch 7 - Val Loss: 1.4197 | Acc: 0.5711 | Precision: 0.5824 | Recall: 0.7089 | F1: 0.6395
#
# Epoch 8/120
# Training: 100%|█████████████████████████████████| 83/83 [02:55<00:00,  2.12s/it]
# Epoch 8 - Train Loss: 0.2100 | Acc: 0.8944 | Precision: 0.9031 | Recall: 0.9199 | F1: 0.9114
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.60it/s]
# Epoch 8 - Val Loss: 1.2668 | Acc: 0.5922 | Precision: 0.5938 | Recall: 0.7599 | F1: 0.6667
#
# Epoch 9/120
# Training: 100%|█████████████████████████████████| 83/83 [02:55<00:00,  2.12s/it]
# Epoch 9 - Train Loss: 0.1992 | Acc: 0.8982 | Precision: 0.9047 | Recall: 0.9250 | F1: 0.9148
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.63it/s]
# Epoch 9 - Val Loss: 1.0654 | Acc: 0.6205 | Precision: 0.6236 | Recall: 0.7385 | F1: 0.6762
#
# Epoch 10/120
# Training: 100%|█████████████████████████████████| 83/83 [02:55<00:00,  2.11s/it]
# Epoch 10 - Train Loss: 0.1989 | Acc: 0.9043 | Precision: 0.9116 | Recall: 0.9279 | F1: 0.9197
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.65it/s]
# Epoch 10 - Val Loss: 0.9678 | Acc: 0.6496 | Precision: 0.6699 | Recall: 0.6842 | F1: 0.6770
# ⭐ Best model updated!
#
# Epoch 11/120
# Training: 100%|█████████████████████████████████| 83/83 [02:53<00:00,  2.09s/it]
# Epoch 11 - Train Loss: 0.1834 | Acc: 0.9065 | Precision: 0.9153 | Recall: 0.9276 | F1: 0.9214
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.66it/s]
# Epoch 11 - Val Loss: 1.0421 | Acc: 0.6593 | Precision: 0.6533 | Recall: 0.7780 | F1: 0.7102
#
# Epoch 12/120
# Training: 100%|█████████████████████████████████| 83/83 [02:50<00:00,  2.05s/it]
# Epoch 12 - Train Loss: 0.1722 | Acc: 0.9145 | Precision: 0.9232 | Recall: 0.9327 | F1: 0.9280
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.65it/s]
# Epoch 12 - Val Loss: 0.7499 | Acc: 0.6646 | Precision: 0.7436 | Recall: 0.5724 | F1: 0.6468
# ⭐ Best model updated!
#
# Epoch 13/120
# Training:  98%|████████████████████████████████▏| 81/83 [02:52<00:03,  1.74s/it]NaN right after forward pass
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  99%|████████████████████████████████▌| 82/83 [02:52<00:01,  1.34s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training: 100%|█████████████████████████████████| 83/83 [02:53<00:00,  2.09s/it]
# Epoch 13 - Train Loss: nan | Acc: 0.9061 | Precision: 0.9241 | Recall: 0.9164 | F1: 0.9202
# Validation: 100%|███████████████████████████████| 18/18 [00:11<00:00,  1.62it/s]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 13 - Val Loss: nan | Acc: 0.4634 | Precision: 0.0000 | Recall: 0.0000 | F1: 0.0000
#
# Epoch 14/120
# Training:   0%|                                          | 0/83 [00:00<?, ?it/s]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   1%|▍                                 | 1/83 [00:12<17:16, 12.64s/it]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:   2%|▊                                 | 2/83 [00:13<07:23,  5.47s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)tensor(nan, device='cuda:1', grad_fn=<MinBackward1>)
# tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   4%|█▏                                | 3/83 [00:13<04:12,  3.16s/it]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NANOUTPUT NAN
#
# Training:   5%|█▋                                | 4/83 [00:17<04:20,  3.30s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:   6%|██                                | 5/83 [00:17<02:55,  2.25s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:   7%|██▍                               | 6/83 [00:17<02:04,  1.62s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>)NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
#  tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   8%|██▊                               | 7/83 [00:18<01:32,  1.22s/it]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  10%|███▎                              | 8/83 [00:25<03:51,  3.09s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  11%|███▋                              | 9/83 [00:25<02:46,  2.25s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  12%|███▉                             | 10/83 [00:26<02:02,  1.68s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  13%|████▎                            | 11/83 [00:26<01:32,  1.29s/it]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  14%|████▊                            | 12/83 [00:33<03:34,  3.02s/it]NaN right after forward pass
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MinBackward1>)tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
#  tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  16%|█████▏                           | 13/83 [00:33<02:36,  2.23s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  17%|█████▌                           | 14/83 [00:34<01:55,  1.67s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  18%|█████▉                           | 15/83 [00:34<01:28,  1.30s/it]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NANLOSS NAN
#
# OUTPUT NANOUTPUT NAN
#
# Training:  19%|██████▎                          | 16/83 [00:41<03:16,  2.93s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  20%|██████▊                          | 17/83 [00:41<02:23,  2.17s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  22%|███████▏                         | 18/83 [00:42<01:46,  1.64s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  23%|███████▌                         | 19/83 [00:42<01:21,  1.27s/it]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS
/it]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  72%|███████████████████████▊         | 60/83 [02:09<01:04,  2.82s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NANLOSS NAN
#
# OUTPUT NAN
# OUTPUT NAN
# Training:  73%|████████████████████████▎        | 61/83 [02:10<00:50,  2.29s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  75%|████████████████████████▋        | 62/83 [02:11<00:36,  1.73s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  76%|█████████████████████████        | 63/83 [02:11<00:26,  1.33s/it]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NANLOSS NAN
#
# OUTPUT NAN
# OUTPUT NAN
# Training:  77%|█████████████████████████▍       | 64/83 [02:17<00:52,  2.78s/it]NaN right after forward pass
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  78%|█████████████████████████▊       | 65/83 [02:19<00:41,  2.32s/it]NaN right after forward pass
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  80%|██████████████████████████▏      | 66/83 [02:19<00:29,  1.75s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  81%|██████████████████████████▋      | 67/83 [02:20<00:21,  1.35s/it]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  82%|███████████████████████████      | 68/83 [02:26<00:41,  2.73s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  83%|███████████████████████████▍     | 69/83 [02:27<00:32,  2.33s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  84%|███████████████████████████▊     | 70/83 [02:27<00:22,  1.75s/it]NaN right after forward pass
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  86%|████████████████████████████▏    | 71/83 [02:28<00:16,  1.34s/it]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  87%|████████████████████████████▋    | 72/83 [02:34<00:30,  2.73s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  88%|█████████████████████████████    | 73/83 [02:35<00:23,  2.31s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  89%|█████████████████████████████▍   | 74/83 [02:35<00:15,  1.73s/it]NaN right after forward pass
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NANLOSS NAN
# OUTPUT NAN
#
# OUTPUT NAN
# Training:  90%|█████████████████████████████▊   | 75/83 [02:36<00:10,  1.33s/it]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  92%|██████████████████████████████▏  | 76/83 [02:42<00:19,  2.81s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NANLOSS NAN
#
# OUTPUT NAN
# OUTPUT NAN
# Training:  93%|██████████████████████████████▌  | 77/83 [02:43<00:13,  2.21s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NANLOSS NAN
#
# OUTPUT NAN
# OUTPUT NAN
# Training:  94%|███████████████████████████████  | 78/83 [02:43<00:08,  1.66s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  95%|███████████████████████████████▍ | 79/83 [02:44<00:05,  1.28s/it]NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  96%|███████████████████████████████▊ | 80/83 [02:48<00:06,  2.22s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  98%|████████████████████████████████▏| 81/83 [02:48<00:03,  1.66s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  99%|████████████████████████████████▌| 82/83 [02:49<00:01,  1.27s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training: 100%|█████████████████████████████████| 83/83 [02:49<00:00,  2.04s/it]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 14 - Train Loss: nan | Acc: 0.4095 | Precision: 0.0000 | Recall: 0.0000 | F1: 0.0000
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.64it/s]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 14 - Val Loss: nan | Acc: 0.4634 | Precision: 0.0000 | Recall: 0.0000 | F1: 0.0000
#
# Epoch 15/120
# Training:   0%|                                          | 0/83 [00:00<?, ?it/s]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:   1%|▍                                 | 1/83 [00:08<11:33,  8.45s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   2%|▊                                 | 2/83 [00:13<08:21,  6.19s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>)tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
#  tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   4%|█▏                                | 3/83 [00:13<04:43,  3.55s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   5%|█▋                                | 4/83 [00:17<04:42,  3.58s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NANLOSS NAN
# OUTPUT NAN
#
# OUTPUT NAN
# Training:   6%|██                                | 5/83 [00:17<03:09,  2.43s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>)NaN right after forward pass
#  tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   7%|██▍                               | 6/83 [00:17<02:14,  1.74s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   8%|██▊                               | 7/83 [00:18<01:38,  1.30s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  10%|███▎                              | 8/83 [00:25<03:49,  3.06s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:
/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  59%|███████████████████▍             | 49/83 [01:46<01:19,  2.34s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  60%|███████████████████▉             | 50/83 [01:47<00:58,  1.76s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  61%|████████████████████▎            | 51/83 [01:47<00:43,  1.36s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  63%|████████████████████▋            | 52/83 [01:53<01:26,  2.79s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  64%|█████████████████████            | 53/83 [01:55<01:12,  2.40s/it]NaN right after forward pass
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# LOSS NANLOSS NAN
#
# OUTPUT NAN
# OUTPUT NAN
# Training:  65%|█████████████████████▍           | 54/83 [01:55<00:52,  1.80s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  66%|█████████████████████▊           | 55/83 [01:56<00:38,  1.38s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  67%|██████████████████████▎          | 56/83 [02:01<01:13,  2.74s/it]NaN right after forward pass
# tensor(nan, device='cuda:0', grad_fn=<MinBackward1>) tensor(nan, device='cuda:0', grad_fn=<MaxBackward1>)
# NaN right after forward pass
# tensor(nan, device='cuda:1', grad_fn=<MinBackward1>) tensor(nan, device='cuda:1', grad_fn=<MaxBackward1>)
# ^C
# W0308 10:56:19.226000 596 torch/distributed/elastic/agent/server/api.py:725] Received 2 death signal, shutting down workers
# W0308 10:56:19.228000 596 torch/distributed/elastic/multiprocessing/api.py:908] Sending process 613 closing signal SIGINT
# W0308 10:56:19.232000 596 torch/distributed/elastic/multiprocessing/api.py:908] Sending process 614 closing signal SIGINT
# Training:  67%|██████████████████████▎          | 56/83 [02:03<00:59,  2.21s/it]
# [rank1]: Traceback (most recent call last):
# [rank1]:   File "/kaggle/working/model.py", line 513, in <module>
# [rank1]:     print("LOSS NAN")
# [rank1]: KeyboardInterrupt
# [rank0]: Traceback (most recent call last):
# [rank0]:   File "/kaggle/working/model.py", line 513, in <module>
# [rank0]:     print("LOSS NAN")
# [rank0]: KeyboardInterrupt

# %%
# !uv pip install evaluate -q
# !accelerate launch model.py --num_processes=2 --mixed_precision=fp16
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `2`
# 		More than one GPU was found, enabling multi-GPU training.
# 		If this was unintended please pass in `--num_processes=1`.
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# [HERE 0]
# [HERE 0]
# Total sequences: 2879
# Positive sequences: 1674
# Negative sequences: 1205
# Total sequences: 2879
# Positive sequences: 1674
# Negative sequences: 1205
# Total sequences: 2406
# Positive sequences: 1447
# Negative sequences: 959
# Total sequences: 2406
# Positive sequences: 1447
# Negative sequences: 959
# Total sequences: 1133
# Positive sequences: 608
# Negative sequences: 525
# [HERE 1]
# Total sequences: 1133
# Positive sequences: 608
# Negative sequences: 525
# [HERE 1]
# [HERE 2]
# [HERE 2]
# [HERE 3]
# [HERE 3]
# [HERE 4]
# [HERE 5]
# [HERE 4]
# [HERE 5]
#
# Epoch 1/120
# Training: 100%|█████████████████████████████████| 83/83 [03:16<00:00,  2.36s/it]
# Epoch 1 - Train Loss: 0.4891 | Acc: 0.6658 | Precision: 0.7296 | Recall: 0.6898 | F1: 0.7092
# Validation: 100%|███████████████████████████████| 18/18 [00:16<00:00,  1.08it/s]
# Epoch 1 - Val Loss: 1.0321 | Acc: 0.4545 | Precision: 0.4892 | Recall: 0.3734 | F1: 0.4235
# ⭐ Best model updated!
#
# Epoch 2/120
# Training: 100%|█████████████████████████████████| 83/83 [02:58<00:00,  2.15s/it]
# Epoch 2 - Train Loss: 0.3633 | Acc: 0.8165 | Precision: 0.8048 | Recall: 0.9100 | F1: 0.8541
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.68it/s]
# Epoch 2 - Val Loss: 1.1696 | Acc: 0.4943 | Precision: 0.5368 | Recall: 0.4194 | F1: 0.4709
#
# Epoch 3/120
# Training: 100%|█████████████████████████████████| 83/83 [02:54<00:00,  2.10s/it]
# Epoch 3 - Train Loss: 0.3164 | Acc: 0.8352 | Precision: 0.8344 | Recall: 0.8994 | F1: 0.8657
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.65it/s]
# Epoch 3 - Val Loss: 1.1509 | Acc: 0.5260 | Precision: 0.5773 | Recall: 0.4359 | F1: 0.4967
#
# Epoch 4/120
# Training: 100%|█████████████████████████████████| 83/83 [02:55<00:00,  2.11s/it]
# Epoch 4 - Train Loss: 0.2815 | Acc: 0.8500 | Precision: 0.8575 | Recall: 0.8946 | F1: 0.8756
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.70it/s]
# Epoch 4 - Val Loss: 1.1588 | Acc: 0.5578 | Precision: 0.5732 | Recall: 0.6891 | F1: 0.6258
#
# Epoch 5/120
# Training: 100%|█████████████████████████████████| 83/83 [02:58<00:00,  2.16s/it]
# Epoch 5 - Train Loss: 0.2591 | Acc: 0.8746 | Precision: 0.8786 | Recall: 0.9138 | F1: 0.8959
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.69it/s]
# Epoch 5 - Val Loss: 1.6770 | Acc: 0.5534 | Precision: 0.5606 | Recall: 0.7763 | F1: 0.6510
#
# Epoch 6/120
# Training: 100%|█████████████████████████████████| 83/83 [02:59<00:00,  2.16s/it]
# Epoch 6 - Train Loss: 0.2373 | Acc: 0.8827 | Precision: 0.8873 | Recall: 0.9180 | F1: 0.9024
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.69it/s]
# Epoch 6 - Val Loss: 1.5691 | Acc: 0.5331 | Precision: 0.5508 | Recall: 0.7039 | F1: 0.6181
#
# Epoch 7/120
# Training: 100%|█████████████████████████████████| 83/83 [03:02<00:00,  2.19s/it]
# Epoch 7 - Train Loss: 0.2233 | Acc: 0.8910 | Precision: 0.8970 | Recall: 0.9212 | F1: 0.9089
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.71it/s]
# Epoch 7 - Val Loss: 1.4197 | Acc: 0.5711 | Precision: 0.5824 | Recall: 0.7089 | F1: 0.6395
#
# Epoch 8/120
# Training: 100%|█████████████████████████████████| 83/83 [02:56<00:00,  2.13s/it]
# Epoch 8 - Train Loss: 0.2100 | Acc: 0.8944 | Precision: 0.9031 | Recall: 0.9199 | F1: 0.9114
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.74it/s]
# Epoch 8 - Val Loss: 1.2668 | Acc: 0.5922 | Precision: 0.5938 | Recall: 0.7599 | F1: 0.6667
#
# Epoch 9/120
# Training: 100%|█████████████████████████████████| 83/83 [02:55<00:00,  2.12s/it]
# Epoch 9 - Train Loss: 0.1992 | Acc: 0.8982 | Precision: 0.9047 | Recall: 0.9250 | F1: 0.9148
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.72it/s]
# Epoch 9 - Val Loss: 1.0654 | Acc: 0.6205 | Precision: 0.6236 | Recall: 0.7385 | F1: 0.6762
#
# Epoch 10/120
# Training: 100%|█████████████████████████████████| 83/83 [02:54<00:00,  2.10s/it]
# Epoch 10 - Train Loss: 0.1989 | Acc: 0.9043 | Precision: 0.9116 | Recall: 0.9279 | F1: 0.9197
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.66it/s]
# Epoch 10 - Val Loss: 0.9678 | Acc: 0.6496 | Precision: 0.6699 | Recall: 0.6842 | F1: 0.6770
# ⭐ Best model updated!
#
# Epoch 11/120
# Training: 100%|█████████████████████████████████| 83/83 [02:58<00:00,  2.15s/it]
# Epoch 11 - Train Loss: 0.1834 | Acc: 0.9065 | Precision: 0.9153 | Recall: 0.9276 | F1: 0.9214
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.64it/s]
# Epoch 11 - Val Loss: 1.0421 | Acc: 0.6593 | Precision: 0.6533 | Recall: 0.7780 | F1: 0.7102
#
# Epoch 12/120
# Training: 100%|█████████████████████████████████| 83/83 [02:55<00:00,  2.12s/it]
# Epoch 12 - Train Loss: 0.1722 | Acc: 0.9145 | Precision: 0.9232 | Recall: 0.9327 | F1: 0.9280
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.71it/s]
# Epoch 12 - Val Loss: 0.7499 | Acc: 0.6646 | Precision: 0.7436 | Recall: 0.5724 | F1: 0.6468
# ⭐ Best model updated!
#
# Epoch 13/120
# Training:  98%|████████████████████████████████▏| 81/83 [03:01<00:03,  1.76s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  99%|████████████████████████████████▌| 82/83 [03:02<00:01,  1.34s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training: 100%|█████████████████████████████████| 83/83 [03:02<00:00,  2.20s/it]
# Epoch 13 - Train Loss: nan | Acc: 0.9061 | Precision: 0.9241 | Recall: 0.9164 | F1: 0.9202
# Validation: 100%|███████████████████████████████| 18/18 [00:10<00:00,  1.72it/s]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 13 - Val Loss: nan | Acc: 0.4634 | Precision: 0.0000 | Recall: 0.0000 | F1: 0.0000
#
# Epoch 14/120
# Training:   0%|                                          | 0/83 [00:00<?, ?it/s]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   1%|▍                                 | 1/83 [00:12<17:20, 12.69s/it]LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:   2%|▊                                 | 2/83 [00:13<07:23,  5.48s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   4%|█▏                                | 3/83 [00:13<04:11,  3.15s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   5%|█▋                                | 4/83 [00:17<04:33,  3.47s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   6%|██                                | 5/83 [00:17<03:03,  2.35s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:   7%|██▍                               | 6/83 [00:18<02:09,  1.68s/it]LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:   8%|██▊                               | 7/83 [00:18<01:35,  1.25s/it]LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  10%|███▎                              | 8/83 [00:25<03:50,  3.07s/it]LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  11%|███▋                              | 9/83 [00:26<02:47,  2.26s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  12%|███▉                             | 10/83 [00:26<02:02,  1.68s/it]LOSS NAN
# LOSS NAN
# OUTPUT NANOUTPUT NAN
#
# Training:  13%|████▎                            | 11/83 [00:26<01:32,  1.28s/it]LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  14%|████▊                            | 12/83 [00:33<03:33,  3.00s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  16%|█████▏                           | 13/83 [00:34<02:42,  2.32s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  17%|█████▌                           | 14/83 [00:34<01:59,  1.73s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  18%|█████▉                           | 15/83 [00:35<01:29,  1.32s/it]LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  19%|██████▎                          | 16/83 [00:41<03:12,  2.87s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  20%|██████▊                          | 17/83 [00:42<02:30,  2.27s/it]LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  22%|███████▏                         | 18/83 [00:42<01:50,  1.70s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  23%|███████▌                         | 19/83 [00:43<01:23,  1.30s/it]LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  24%|███████▉                         | 20/83 [00:49<02:59,  2.85s/it]LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  25%|████████▎                        | 21/83 [00:50<02:19,  2.26s/it]LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:  27%|████████▋                        | 22/83 [00:51<01:43,  1.69s/it]LOSS NAN
# LOSS NAN
# OUTPUT NAN
# OUTPUT NAN
# Training:  28%|█████████▏                       | 23/83 [00:51<01:17,  1.29s/it]LOSS NAN
# OUTPUT NAN
# LOSS NAN
# OUTPUT NAN
# Training:

# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 16 - Train Loss: nan | Acc: 0.4095 | Precision: 0.0000 | Recall: 0.0000 | F1: 0.0000
# Validation:   0%|                                        | 0/18 [00:00<?, ?it/s]^C
# W0308 09:55:57.967000 221 torch/distributed/elastic/agent/server/api.py:725] Received 2 death signal, shutting down workers
# W0308 09:55:57.970000 221 torch/distributed/elastic/multiprocessing/api.py:908] Sending process 238 closing signal SIGINT
# Validation:   0%|                                        | 0/18 [00:00<?, ?it/s]
# W0308 09:55:57.977000 221 torch/distributed/elastic/multiprocessing/api.py:908] Sending process 239 closing signal SIGINT
# [rank0]: Traceback (most recent call last):
# [rank0]:   File "/kaggle/working/model.py", line 544, in <module>
# [rank0]:     for frames, labels in val_bar:
# [rank0]:                           ^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
# [rank0]:     for obj in iterable:
# [rank0]:                ^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/accelerate/data_loader.py", line 567, in __iter__
# [rank0]:     current_batch = next(dataloader_iter)
# [rank0]:                     ^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 732, in __next__
# [rank0]:     data = self._next_data()
# [rank0]:            ^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1482, in _next_data
# [rank0]:     idx, data = self._get_data()
# [rank0]:                 ^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1434, in _get_data
# [rank0]:     success, data = self._try_get_data()
# [rank0]:                     ^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1275, in _try_get_data
# [rank0]:     data = self._data_queue.get(timeout=timeout)
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]:   File "/usr/lib/python3.12/queue.py", line 180, in get
# [rank0]:     self.not_empty.wait(remaining)
# [rank0]:   File "/usr/lib/python3.12/threading.py", line 359, in wait
# [rank0]:     gotit = waiter.acquire(True, timeout)
# [rank0]:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]: KeyboardInterrupt
# [rank1]: Traceback (most recent call last):
# [rank1]:   File "/kaggle/working/model.py", line 544, in <module>
# [rank1]:     for frames, labels in val_bar:
# [rank1]:                           ^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1169, in __iter__
# [rank1]:     for obj in iterable:
# [rank1]:                ^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/accelerate/data_loader.py", line 567, in __iter__
# [rank1]:     current_batch = next(dataloader_iter)
# [rank1]:                     ^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 732, in __next__
# [rank1]:     data = self._next_data()
# [rank1]:            ^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1482, in _next_data
# [rank1]:     idx, data = self._get_data()
# [rank1]:                 ^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1434, in _get_data
# [rank1]:     success, data = self._try_get_data()
# [rank1]:                     ^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1275, in _try_get_data
# [rank1]:     data = self._data_queue.get(timeout=timeout)
# [rank1]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]:   File "/usr/lib/python3.12/queue.py", line 180, in get
# [rank1]:     self.not_empty.wait(remaining)
# [rank1]:   File "/usr/lib/python3.12/threading.py", line 359, in wait
# [rank1]:     gotit = waiter.acquire(True, timeout)
# [rank1]:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]: KeyboardInterrupt
