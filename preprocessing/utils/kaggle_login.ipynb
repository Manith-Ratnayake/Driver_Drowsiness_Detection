# %%
import os
# !uv pip install -U kagglehub
# !mkdir -p ~/.kaggle
# !echo "KAGGLE_USERNAME=manith04" > ~/.kaggle/kaggle.json
# !echo "KAGGLE_KEY=KGAT_28e717b9ccd1d5f6908afdf6559d8cb4" >> ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json
# !export KAGGLE_USERNAME=manith04 && export KAGGLE_KEY=KGAT_28e717b9ccd1d5f6908afdf6559d8cb4
os.environ["KAGGLE_USERNAME"] = "manith04"
os.environ["KAGGLE_KEY"] = "KGAT_28e717b9ccd1d5f6908afdf6559d8cb4"
os.environ["KAGGLE_API_TOKEN"] = "KGAT_28e717b9ccd1d5f6908afdf6559d8cb4"

# !export KAGGLE_API_TOKEN=KGAT_28e717b9ccd1d5f6908afdf6559d8cb4
# !uv pip install -U kagglehub
# kagglehub.login()
# %cd output
# !kaggle datasets init -p .
